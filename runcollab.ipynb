# %% [markdown]
# Connect google collab with t4 then Donwload source code

# %%
# !git clone https://github.com/mdikifahriza/adaptssp
# !cp -r /content/adaptssp/. /content/
# !rm -rf /content/sample_data /content/adaptssp
# !cd /content && ls -la
# Out:
# Cloning into 'adaptssp'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (351/351), done.
# remote: Compressing objects: 100% (215/215), done.
# remote: Total 351 (delta 148), reused 326 (delta 123), pack-reused 0 (from 0)
# Receiving objects: 100% (351/351), 7.31 MiB | 6.10 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# total 84
# drwxr-xr-x 1 root root  4096 Sep 25 10:23 .
# drwxr-xr-x 1 root root  4096 Sep 25 09:55 ..
# drwxr-xr-x 3 root root  4096 Sep 25 10:21 build
# -rw-r--r-- 1 root root  2196 Sep 25 10:23 CMakeLists.txt
# drwxr-xr-x 4 root root  4096 Sep  4 13:32 .config
# drwxr-xr-x 3 root root  4096 Sep 25 10:08 external
# drwxr-xr-x 8 root root  4096 Sep 25 10:08 .git
# -rw-r--r-- 1 root root    25 Sep 25 10:22 instance_n24.sol
# -rw-r--r-- 1 root root 37154 Sep 25 10:23 runcollab.ipynb
# drwxr-xr-x 2 root root  4096 Sep 25 10:08 src
# drwxr-xr-x 2 root root  4096 Sep 25 10:08 work

# %% [markdown]
# Clone argparse

# %%
# !git clone --depth 1 https://github.com/p-ranav/argparse.git external/argparse
# Out:
# Cloning into 'external/argparse'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 93 (delta 15), reused 50 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 149.95 KiB | 12.50 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %% [markdown]
# Build

# %%
# %cd /content
# !cmake -S . -B build -DCMAKE_BUILD_TYPE=Release
# !cmake --build build -j2
# !ls -la build
# Out:
# /content
# -- Configuring done (0.0s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/build
# [ 20%] Building CXX object CMakeFiles/adaptssp.dir/src/main.cpp.o
# [ 40%] Building CXX object CMakeFiles/adaptssp.dir/src/ter_solver.cpp.o
# [ 60%] Building CUDA object CMakeFiles/adaptssp.dir/src/ter_kernel.cu.o
# [ 80%] Building CUDA object CMakeFiles/adaptssp.dir/src/ss_kernel.cu.o
# [100%] Linking CXX executable adaptssp
# [100%] Built target adaptssp
# total 3268
# drwxr-xr-x 3 root root    4096 Sep 25 10:21 .
# drwxr-xr-x 1 root root    4096 Sep 25 10:12 ..
# -rwxr-xr-x 1 root root 2742296 Sep 25 10:21 adaptssp
# -rw-r--r-- 1 root root  535900 Sep 25 10:08 adapt_ssp_cpu.exe
# -rw-r--r-- 1 root root   32884 Sep 25 10:20 CMakeCache.txt
# drwxr-xr-x 6 root root    4096 Sep 25 10:21 CMakeFiles
# -rw-r--r-- 1 root root    2045 Sep 25 10:20 cmake_install.cmake
# -rw-r--r-- 1 root root    7908 Sep 25 10:20 Makefile

# %%
# !./build/adaptssp work/instance_n16.prb --solver ter --autorestart
# Out:
# max_pairs_per_chunk auto-calibrated: 127554662 (from 12.6714 GB budget, auto-detected RAM)
# CPU threads: 2 (auto-detected)
# Reading instance from file work/instance_n16.prb; instance_name instance_n16
# Detected 1D subset-sum instance: n=16, target=347884
# [TER] Menggunakan TER Solver (Yang Li et al., 2025)
#
# ...
# TER (Ternary Enumeration Representation) Solver Started
# ...
# Instance size n : 16
# Target value    : 347884
# Matching bits   : b1=19, b2=11
# Sum-wrap check  : total_sum/2^b1 >= 1 (b1=19, sum_bits=20): subset-sum membungkus modulus L1.
# Target capacities: L3=4096, L2=8192, L1=8192
# Execution mode  : Hybrid CPU (OpenMP) + GPU (Tesla T4 / CUDA) for Level 1 merge
# Level 1 lookup  : sidecar key + bucket (auto; fallback binary search jika syarat bucket tidak terpenuhi)
# Restart config  : fixed_runs=0, max_restarts=0, timeout=0s
#
# Generated Base Pool: Left=4105 entries, Right=4105 entries
# [TER-PROFIL] waktu sekali-jalan: gen_pool=0.0008s sort_pool_right=0.0004s
# ...

# %%
# !./build/adaptssp work/instance_n24.prb --solver ter --autorestart
# Out:
# max_pairs_per_chunk auto-calibrated: 127554662 (from 12.6714 GB budget, auto-detected RAM)
# CPU threads: 2 (auto-detected)
# Reading instance from file work/instance_n24.prb; instance_name instance_n24
# Detected 1D subset-sum instance: n=24, target=139114178
# [TER] Menggunakan TER Solver (Yang Li et al., 2025)
#
# ...
# TER (Ternary Enumeration Representation) Solver Started
# ...
# Instance size n : 24
# Target value    : 139114178
# Matching bits   : b1=28, b2=11
# Sum-wrap check  : total_sum/2^b1 >= 1 (b1=28, sum_bits=29): subset-sum membungkus modulus L1.
# Target capacities: L3=4096, L2=8192, L1=8192
# Execution mode  : Hybrid CPU (OpenMP) + GPU (Tesla T4 / CUDA) for Level 1 merge
# Level 1 lookup  : sidecar key + bucket (auto; fallback binary search jika syarat bucket tidak terpenuhi)
# Restart config  : fixed_runs=0, max_restarts=0, timeout=0s
#
# Generated Base Pool: Left=6779 entries, Right=6779 entries
# [TER-PROFIL] waktu sekali-jalan: gen_pool=0.0006s sort_pool_right=0.0005s
# ...

# %%
# !./build/adaptssp work/instance_n32.prb --solver ter --autorestart
# Out:
# max_pairs_per_chunk auto-calibrated: 127554662 (from 12.6714 GB budget, auto-detected RAM)
# CPU threads: 2 (auto-detected)
# Reading instance from file work/instance_n32.prb; instance_name instance_n32
# Detected 1D subset-sum instance: n=32, target=48449542436
# [TER] Menggunakan TER Solver (Yang Li et al., 2025)
#
# ...
# TER (Ternary Enumeration Representation) Solver Started
# ...
# Instance size n : 32
# Target value    : 48449542436
# Matching bits   : b1=31, b2=11
# Sum-wrap check  : total_sum/2^b1 >= 1 (b1=31, sum_bits=37): subset-sum membungkus modulus L1.
# Target capacities: L3=4096, L2=8192, L1=8192
# Execution mode  : Hybrid CPU (OpenMP) + GPU (Tesla T4 / CUDA) for Level 1 merge
# Level 1 lookup  : sidecar key + bucket (auto; fallback binary search jika syarat bucket tidak terpenuhi)
# Restart config  : fixed_runs=0, max_restarts=0, timeout=0s
#
# Generated Base Pool: Left=4313 entries, Right=4313 entries
# [TER-PROFIL] waktu sekali-jalan: gen_pool=0.0006s sort_pool_right=0.0004s
# ...

# %%
# !./build/adaptssp work/instance_n40.prb --solver ter --autorestart
# Out:
# max_pairs_per_chunk auto-calibrated: 127554662 (from 12.6714 GB budget, auto-detected RAM)
# CPU threads: 2 (auto-detected)
# Reading instance from file work/instance_n40.prb; instance_name instance_n40
# Detected 1D subset-sum instance: n=40, target=17382594727021
# [TER] Menggunakan TER Solver (Yang Li et al., 2025)
#
# ...
# TER (Ternary Enumeration Representation) Solver Started
# ...
# Instance size n : 40
# Target value    : 17382594727021
# Matching bits   : b1=32, b2=11
# Sum-wrap check  : total_sum/2^b1 >= 1 (b1=32, sum_bits=45): subset-sum membungkus modulus L1.
# Target capacities: L3=4096, L2=8192, L1=8192
# Execution mode  : Hybrid CPU (OpenMP) + GPU (Tesla T4 / CUDA) for Level 1 merge
# Level 1 lookup  : sidecar key + bucket (auto; fallback binary search jika syarat bucket tidak terpenuhi)
# Restart config  : fixed_runs=0, max_restarts=0, timeout=0s
#
# Generated Base Pool: Left=7451 entries, Right=7451 entries
# ...

# %% [markdown]
# This may take longer

# %%
# !./build/adaptssp work/instance_n48.prb --solver ter --autorestart

# %%
# !./build/adaptssp work/instance_n56.prb --solver ter --autorestart

# %% [markdown]
# download all soll files

# %%
# !find /content -type f -name "*.sol" -print
# !zip -j /content/sol_files.zip $(find /content -type f -name "*.sol")
from google.colab import files
files.download('/content/sol_files.zip')
rm -rf
# Out:
# /content/work/instance_n32.sol
# /content/work/instance_n56.sol
# /content/work/instance_n24.sol
# /content/work/instance_n64.sol
# /content/work/instance_n40.sol
# /content/work/instance_n48.sol
# /content/work/instance_n16.sol
#   adding: instance_n32.sol (deflated 42%)
#   adding: instance_n56.sol (deflated 54%)
#   adding: instance_n24.sol (deflated 44%)
#   adding: instance_n64.sol (deflated 54%)
#   adding: instance_n40.sol (deflated 49%)
#   adding: instance_n48.sol (deflated 49%)
#   adding: instance_n16.sol (deflated 18%)
